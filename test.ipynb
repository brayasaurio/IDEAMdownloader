# %%
from src.utils import ideam_downloader
from src.utils import variables_station

Codigo = 12017010

ideam_downloader(code=Codigo, varible=variables_station(Codigo))

# %%
from src.utils import ideam_downloader


Codigo = 21206980

varibles = ['HUM RELATIVA.HRA10_AUT_60@21206980',
'HUM RELATIVA.HRA10_MEDIA_A@21206980',
'HUM RELATIVA.HRA10_MEDIA_D@21206980',
'HUM RELATIVA.HRA10_MEDIA_M@21206980',
'HUM RELATIVA.HRA10_MN_A@21206980',
'HUM RELATIVA.HRA10_MN_D@21206980',
'HUM RELATIVA.HRA10_MN_M@21206980',
'HUM RELATIVA.HRA10_MX_A@21206980',
'HUM RELATIVA.HRA10_MX_D@21206980',
'HUM RELATIVA.HRA10_MX_M@21206980',
'HUM RELATIVA.HRA2_AUT_60@21206980',
'HUM RELATIVA.HRA2_MEDIA_A@21206980',
'HUM RELATIVA.HRA2_MEDIA_D@21206980',
'HUM RELATIVA.HRA2_MEDIA_M@21206980',
'HUM RELATIVA.HRA2_MN_A@21206980',
'HUM RELATIVA.HRA2_MN_D@21206980',
'HUM RELATIVA.HRA2_MN_M@21206980',
'HUM RELATIVA.HRA2_MX_A@21206980',
'HUM RELATIVA.HRA2_MX_D@21206980',
'HUM RELATIVA.HRA2_MX_M@21206980',
'PRECIPITACION.PT_10_MX_A@21206980',
'PRECIPITACION.PT_10_MX_D@21206980',
'PRECIPITACION.PT_10_MX_M@21206980',
'PRECIPITACION.PT_10_MX_TT_A@21206980',
'PRECIPITACION.PT_10_MX_TT_M@21206980',
'PRECIPITACION.PT_10_TT_A@21206980',
'PRECIPITACION.PT_10_TT_D@21206980',
'PRECIPITACION.PT_10_TT_H@21206980',
'PRECIPITACION.PT_10_TT_M@21206980',
'PRECIPITACION.PT_AUT_10@21206980',
'PRECIPITACION.PTPM_CON@21206980',
'RAD SOLAR.RSG_AUT_60@21206980',
'RAD SOLAR.RSGVAL_AUT_60@21206980',
'RAD SOLAR.RSV_AUT_60@21206980',
'TEMP SUELO.TS20_AUT_60@21206980',
'TEMPERATURA.TA10_AUT_60@21206980',
'TEMPERATURA.TA10_MEDIA_A@21206980',
'TEMPERATURA.TA10_MEDIA_D@21206980',
'TEMPERATURA.TA10_MEDIA_M@21206980',
'TEMPERATURA.TA10_MN_A@21206980',
'TEMPERATURA.TA10_MN_D@21206980',
'TEMPERATURA.TA10_MN_M@21206980',
'TEMPERATURA.TA10_MX_A@21206980',
'TEMPERATURA.TA10_MX_D@21206980',
'TEMPERATURA.TA10_MX_M@21206980',
'TEMPERATURA.TA2_AUT_60@21206980',
'TEMPERATURA.TA2_MEDIA_A@21206980',
'TEMPERATURA.TA2_MEDIA_D@21206980',
'TEMPERATURA.TA2_MEDIA_M@21206980',
'TEMPERATURA.TA2_MN_A@21206980',
'TEMPERATURA.TA2_MN_M@21206980',
'TEMPERATURA.TA2_MX_A@21206980',
'TEMPERATURA.TA2_MX_D@21206980',
'TEMPERATURA.TA2_MX_M@21206980',
'TEMPERATURA.TAMN10_AUT_60@21206980',
'TEMPERATURA.TAMN10_MEDIA_A@21206980',
'TEMPERATURA.TAMN10_MEDIA_D@21206980',
'TEMPERATURA.TAMN10_MEDIA_M@21206980',
'TEMPERATURA.TAMN10_MN_A@21206980',
'TEMPERATURA.TAMN10_MN_D@21206980',
'TEMPERATURA.TAMN10_MN_M@21206980',
'TEMPERATURA.TAMN10_MX_A@21206980',
'TEMPERATURA.TAMN10_MX_D@21206980',
'TEMPERATURA.TAMN10_MX_M@21206980',
'TEMPERATURA.TAMN2_AUT_60@21206980',
'TEMPERATURA.TAMN2_MEDIA_A@21206980',
'TEMPERATURA.TAMN2_MEDIA_D@21206980',
'TEMPERATURA.TAMN2_MEDIA_M@21206980',
'TEMPERATURA.TAMN2_MN_A@21206980',
'TEMPERATURA.TAMN2_MN_D@21206980',
'TEMPERATURA.TAMN2_MN_M@21206980',
'TEMPERATURA.TAMN2_MX_A@21206980',
'TEMPERATURA.TAMN2_MX_D@21206980',
'TEMPERATURA.TAMN2_MX_M@21206980',
'TEMPERATURA.TAMX10_AUT_60@21206980',
'TEMPERATURA.TAMX10_MEDIA_A@21206980',
'TEMPERATURA.TAMX10_MEDIA_D@21206980',
'TEMPERATURA.TAMX10_MEDIA_M@21206980',
'TEMPERATURA.TAMX10_MN_A@21206980',
'TEMPERATURA.TAMX10_MN_D@21206980',
'TEMPERATURA.TAMX10_MN_M@21206980',
'TEMPERATURA.TAMX10_MX_A@21206980',
'TEMPERATURA.TAMX10_MX_D@21206980',
'TEMPERATURA.TAMX10_MX_M@21206980',
'TEMPERATURA.TAMX2_AUT_60@21206980',
'TEMPERATURA.TAMX2_MEDIA_A@21206980',
'TEMPERATURA.TAMX2_MEDIA_D@21206980',
'TEMPERATURA.TAMX2_MEDIA_M@21206980',
'TEMPERATURA.TAMX2_MN_A@21206980',
'TEMPERATURA.TAMX2_MN_D@21206980',
'TEMPERATURA.TAMX2_MN_M@21206980',
'TEMPERATURA.TAMX2_MX_A@21206980',
'TEMPERATURA.TAMX2_MX_D@21206980',
'TEMPERATURA.TAMX2_MX_M@21206980',
'VEL VIENTO.VV_10_MEDIA_A@21206980',
'VEL VIENTO.VV_10_MEDIA_D@21206980',
'VEL VIENTO.VV_10_MEDIA_H@21206980',
'VEL VIENTO.VV_10_MEDIA_M@21206980',
'VEL VIENTO.VV_10_PERSISTENCIA_A@21206980',
'VEL VIENTO.VV_10_PERSISTENCIA_D@21206980',
'VEL VIENTO.VV_10_PERSISTENCIA_M@21206980',
'VEL VIENTO.VV_10_VECT_MEDIA_A@21206980',
'VEL VIENTO.VV_10_VECT_MEDIA_D@21206980',
'VEL VIENTO.VV_10_VECT_MEDIA_M@21206980',
'VEL VIENTO.VV_AUT_10@21206980',
'VEL VIENTO.VVMX_AUT_60@21206980',
'VEL VIENTO.VVMX_MX_A@21206980',
'VEL VIENTO.VVMX_MX_D@21206980',
'VEL VIENTO.VVMX_MX_M@21206980',]

ideam_downloader(code=Codigo, varible=varibles)
# Out:
# ha ocurrido un error de tipo 'NoneType' object has no attribute 'click'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\pc\Documents\IDEAMdownloader\src\utils.py:51, in ideam_downloader(code, varible, waiting_time)
#      49 browser.find_element(By.XPATH, '//div[4]/div/div[2]/div[2]/div[3]/div/div/div[3]/ul/li/a/span[2]').click()
# ---> 51 browser.find_element(By.XPATH, '//div[6]/ul/li[6]/a/span[2]').click()
#      53 browser.find_element(By.XPATH, '//div/span/button/span').click()
#
# AttributeError: 'NoneType' object has no attribute 'click'
#
# During handling of the above exception, another exception occurred:
#
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[9], line 116
#       4 Codigo = 21206980
#       6 varibles = ['HUM RELATIVA.HRA10_AUT_60@21206980',
#       7 'HUM RELATIVA.HRA10_MEDIA_A@21206980',
# ...
